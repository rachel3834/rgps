# %% [markdown]
# # Input catalogs
#
# Various classes of astronomical objects of interests are typically shared as catalogs of targets, such as star clusters, Star Forming Regions etc.  This notebook develops IO functions to handle the different formats.

# %%
import csv
from os import path
from astropy.table import Table, Column
from astropy.io import fits
import numpy as np 
import healpy as hp

# Configure path to local repository
root_dir = '/Users/rstreet/software/rgps'

# %% [markdown]
# The first input catalog received is a set of Star Forming Regions in CSV format, courtesy of Matthew De Furio.

# %%
def load_catalog(root_dir, catalog_name):
    """
    Function to load a catalog of regions, defined as centroid locations plus a radial extent from that
    centroid, which is assumed to be circular.  Centroids can be defined in RA, Dec or (l,b), but
    all quantities should be in decimal degrees.  Since the catalogs have been shared in CSV format
    from different authors, this function handles the formatting specific to each catalog.

    :param root_dir: Path to the config directory where the catalog file can be found
    :param catalog_name: Name of the catalog file
    :return:
    pointing_set: List of dictionaries in the form {"pointing": [l_center, b_center, radius]} in decimal degrees
    """

    catalog_file = path.join(root_dir, catalog_name)
    if not path.isfile(catalog_file):
        raise IOError('Cannot find requested catalog ' + catalog_file)

    pointing_set = []

    if catalog_name == 'SFRs_for_Roman.csv':

        with open(catalog_file) as csv_file:
            csv_reader = csv.reader(csv_file, delimiter=',')
            for i,row in enumerate(csv_reader):
                if i == 0:
                    header = row
                else:
                    pointing_set.append({"pointing": [float(row[4]), float(row[5]), float(row[7])]})

    return pointing_set

# %%
pointings = load_catalog(path.join(root_dir, 'config'), 'SFRs_for_Roman.csv')
pointings
# Out:
# [{'pointing': [264.5, 1.7, 0.6]},
#  {'pointing': [78.5, 2.7, 0.6]},
#  {'pointing': [356.5, -0.7, 0.6]},
#  {'pointing': [85.2, -0.9, 0.7]},
#  {'pointing': [266.5, -3.6, 0.9]},
#  {'pointing': [78.9, 0.7, 0.7]},
#  {'pointing': [245.2, -3.6, 1.0]},
#  {'pointing': [261.4, 1.0, 0.7]},
#  {'pointing': [280.7, 4.3, 0.8]},
#  {'pointing': [181.4, -2.6, 0.7]},
#  {'pointing': [341.3, -2.9, 1.1]},
#  {'pointing': [57.6, -1.3, 1.2]},
#  {'pointing': [57.3, 1.3, 1.0]},
#  {'pointing': [33.8, 1.5, 1.2]},
#  {'pointing': [195.5, -2.8, 1.1]},
#  {'pointing': [260.0, 2.8, 1.6]},
#  {'pointing': [202.8, 1.9, 1.4]},
#  {'pointing': [269.2, 0.0, 1.5]},
#  {'pointing': [91.0, 2.7, 1.4]},
#  {'pointing': [240.0, -2.4, 1.6]},
#  {'pointing': [256.2, -3.4, 1.5]},
#  {'pointing': [255.9, -2.3, 2.0]},
#  {'pointing': [119.1, 3.4, 1.8]},
#  {'pointing': [104.2, -3.9, 1.2]},
#  {'pointing': [248.4, -0.5, 1.5]},
#  {'pointing': [56.1, 3.2, 1.8]},
#  {'pointing': [70.5, -0.2, 2.5]},
#  {'pointing': [85.3, -0.7, 2.0]},
#  {'pointing': [127.3, 1.8, 2.9]},
#  {'pointing': [101.8, -0.3, 1.3]},
#  {'pointing': [84.4, 1.9, 1.9]},
#  {'pointing': [318.3, -2.5, 2.7]},
#  {'pointing': [121.9, -0.7, 2.5]},
#  {'pointing': [97.9, -2.8, 3.3]},
#  {'pointing': [338.7, -1.7, 2.8]},
#  {'pointing': [27.2, 3.2, 3.6]},
#  {'pointing': [348.1, 1.7, 4.3]},
#  {'pointing': [314.9, -6.6, 2.2]},
#  {'pointing': [56.0, 2.0, 3.2]},
#  {'pointing': [114.2, -3.7, 3.7]},
#  {'pointing': [253.2, -7.7, 3.0]},
#  {'pointing': [104.5, 4.4, 4.1]},
#  {'pointing': [276.0, -0.2, 2.7]},
#  {'pointing': [116.1, 3.2, 6.7]},
#  {'pointing': [296.4, -10.1, 5.0]},
#  {'pointing': [111.7, 5.7, 8.7]},
#  {'pointing': [260.4, -8.3, 8.3]},
#  {'pointing': [66.9, 12.9, 7.1]},
#  {'pointing': [179.7, -15.6, 13.2]},
#  {'pointing': [205.7, -18.5, 10.4]},
#  {'pointing': [170.3, -5.5, 8.9]},
#  {'pointing': [333.9, 11.7, 21.5]}]

# %% [markdown]
# Next, we have a catalog of AGNs previously observed by Fermi-LAT obtained from their [Data Release 3](https://fermi.gsfc.nasa.gov/ssc/data/access/lat/4LACDR3/) on the recommendation of Filippo D'Ammando.

# %%
def load_AGN_catalog(root_dir, catalog_name):
    """
    Function to load a source catalog from Fermi-LAT DR3.
    """
    catalog_file = path.join(root_dir, catalog_name)
    if not path.isfile(catalog_file):
        raise IOError('Cannot find requested catalog ' + catalog_file)

    pointing_set = []
    
    with fits.open(catalog_file) as hdul:
        data = hdul[1].data
        for row in data:
            pointing_set.append({"pointing": [float(row[4]), float(row[5]), 0.3]})
    
    return pointing_set

# %%
pointing_set = load_AGN_catalog(path.join(root_dir, 'config'), 'table-4LAC-DR3-l.fits')
print(pointing_set)
# Out:
# [{'pointing': [119.66110229492188, 8.111637115478516, 0.3]}, {'pointing': [118.07474517822266, -4.498106479644775, 0.3]}, {'pointing': [118.55729675292969, -1.2571890354156494, 0.3]}, {'pointing': [117.88809967041016, -6.657064437866211, 0.3]}, {'pointing': [120.17926788330078, 6.626677513122559, 0.3]}, {'pointing': [121.07728576660156, -1.2922883033752441, 0.3]}, {'pointing': [120.98204803466797, -2.9796204566955566, 0.3]}, {'pointing': [121.7068099975586, -1.9695024490356445, 0.3]}, {'pointing': [122.31592559814453, 5.174300193786621, 0.3]}, {'pointing': [122.32572174072266, -5.906441688537598, 0.3]}, {'pointing': [122.42411804199219, -8.066608428955078, 0.3]}, {'pointing': [124.32300567626953, -4.064716815948486, 0.3]}, {'pointing': [124.4244613647461, -4.429605960845947, 0.3]}, {'pointing': [124.74527740478516, -9.203022003173828, 0.3]}, {'pointing': [125.11431121826172, -1.2325012683868408, 0.3]}, {'pointing': [124.68570709228516, 5.289400577545166, 0.3]}, {'pointing': [125.38182067871094, 1.5399152040481567, 0.3]}, {'pointing': [127.93922424316406, -5.342601299285889, 0.3]}, {'pointing': [127.15824127197266, 0.6493514776229858, 0.3]}, {'pointing': [127.67886352539062, -1.1678184270858765, 0.3]}, {'pointing': [128.55210876464844, -6.6514153480529785, 0.3]}, {'pointing': [129.447021484375, -8.68398666381836, 0.3]}, {'pointing': [129.0400848388672, -4.069273948669434, 0.3]}, {'pointing': [131.74505615234375, -9.872842788696289, 0.3]}, {'pointing': [131.591064453125, -6.937782287597656, 0.3]}, {'pointing': [127.9242935180664, 8.97291374206543, 0.3]}, {'pointing': [133.50148010253906, -7.1902923583984375, 0.3]}, {'pointing': [131.19366455078125, 3.0225744247436523, 0.3]}, {'pointing': [135.753173828125, -9.038097381591797, 0.3]}, {'pointing': [131.24452209472656, 6.984189510345459, 0.3]}, {'pointing': [136.2191619873047, -6.229010581970215, 0.3]}, {'pointing': [132.13475036621094, 6.1906232833862305, 0.3]}, {'pointing': [133.9117889404297, 5.227936744689941, 0.3]}, {'pointing': [139.60244750976562, -6.963812828063965, 0.3]}, {'pointing': [140.8017120361328, -7.225923538208008, 0.3]}, {'pointing': [138.88255310058594, -2.6161081790924072, 0.3]}, {'pointing': [141.76600646972656, -7.272125720977783, 0.3]}, {'pointing': [140.70526123046875, -3.503725290298462, 0.3]}, {'pointing': [144.9909210205078, -9.8544340133667, 0.3]}, {'pointing': [134.74488830566406, 8.591056823730469, 0.3]}, {'pointing': [144.55149841308594, -7.819713592529297, 0.3]}, {'pointing': [134.97488403320312, 9.401510238647461, 0.3]}, {'pointing': [137.41836547851562, 7.5824198722839355, 0.3]}, {'pointing': [148.24996948242188, -8.08228588104248, 0.3]}, {'pointing': [149.07095336914062, -7.649857044219971, 0.3]}, {'pointing': [139.95448303222656, 5.69434928894043, 0.3]}, {'pointing': [138.67202758789062, 7.841919422149658, 0.3]}, {'pointing': [150.23687744140625, -4.6010589599609375, 0.3]}, {'pointing': [143.02342224121094, 4.811793804168701, 0.3]}, {'pointing': [152.09075927734375, -6.414720058441162, 0.3]}, {'pointing': [145.83790588378906, 2.34023380279541, 0.3]}, {'pointing': [152.48377990722656, -5.379566192626953, 0.3]}, {'pointing': [144.37741088867188, 5.26141357421875, 0.3]}, {'pointing': [150.40049743652344, -1.59031081199646, 0.3]}, {'pointing': [141.75363159179688, 8.930928230285645, 0.3]}, {'pointing': [157.66250610351562, -6.754054546356201, 0.3]}, {'pointing': [161.59307861328125, -8.766495704650879, 0.3]}, {'pointing': [160.37965393066406, -7.027734756469727, 0.3]}, {'pointing': [159.70265197753906, -5.384661674499512, 0.3]}, {'pointing': [144.4049835205078, 9.769478797912598, 0.3]}, {'pointing': [161.08428955078125, -2.5341551303863525, 0.3]}, {'pointing': [167.97909545898438, -7.356888771057129, 0.3]}, {'pointing': [171.73919677734375, -9.05914306640625, 0.3]}, {'pointing': [151.13888549804688, 8.320268630981445, 0.3]}, {'pointing': [166.8354949951172, -3.966783046722412, 0.3]}, {'pointing': [153.46734619140625, 7.709446430206299, 0.3]}, {'poin ...

# %% [markdown]
# There is a catalog of Globular Clusters, in a different CSV format...

# %% [markdown]
# catalog_file = path.join(root_dir, 'config', 'baumgardt_harris_GCs.csv')
#
# pointing_set = []
#
# pixscale = hp.max_pixrad(64,degrees=True)
#
# with open(catalog_file, newline='') as csv_file:
#     csv_reader = csv.reader(csv_file, delimiter=' ', quotechar='|')
#     for i,row in enumerate(csv_reader):
#         if i >= 1:
#             entries = row[0].split(',')
#             print(entries)
#
#             # The cluster radius is set to 1.5*half-light radius
#             # The half-light radius is r_hl(pc) / R_sun(kpc) converted to deg
#             # However, the radius needs to have a minimum of at least one HEALpixel to register
#             # on the map
#             try:
#                 radius = max((1.5 * (0.001 * float(entries[16]) / float(entries[5])) * 2.0 * (180.0 / np.pi)),
#                          pixscale)
#                 pointing_set.append({"pointing": [float(entries[3]), float(entries[4]), radius]})
#
#             # Skip malformed catalog entries
#             except ValueError:
#                 pass

# %% [markdown]
# An alternative version of the Baumgardt catalog was also provided by Dante Minniti, in a slightly different format.

# %% [markdown]
# Updated catalogs of Open Clusters have been produced recently based on new Gaia data, notably by Cantat-Gaudin (2022), and Hunt & Reffert (2023). Here we use the latter catalog downloaded as a FITS binary table from Vizier.

# %%
catalog_file = path.join(root_dir, 'config', 'hunt_openclusters.fits')

pointing_set = []

pixscale = hp.max_pixrad(64,degrees=True)

with fits.open(catalog_file) as hdul:
        data = hdul[1].data
        for row in data:
            pointing_set.append({"pointing": [float(row[8]), float(row[9]), row[11]]})

print(pointing_set)
# Out:
# [{'pointing': [112.50889463, -2.6679999828338623, np.float64(8.48997672)]}, {'pointing': [243.20021931, -0.6276000142097473, np.float64(0.14630377)]}, {'pointing': [123.84274797, -7.031000137329102, np.float64(0.23229151)]}, {'pointing': [130.3636862, -4.323999881744385, np.float64(0.86658699)]}, {'pointing': [137.8066871, -1.7330000400543213, np.float64(0.33496984)]}, {'pointing': [150.55167577, -9.23799991607666, np.float64(0.60387783)]}, {'pointing': [163.01816915, -1.899999976158142, np.float64(1.32440674)]}, {'pointing': [163.52977738, 3.072000026702881, np.float64(0.86654288)]}, {'pointing': [171.77059711, -1.1080000400543213, np.float64(0.43050422)]}, {'pointing': [202.39396825, -18.889999389648438, np.float64(0.6575184)]}, {'pointing': [204.78898604, -19.3799991607666, np.float64(0.75889465)]}, {'pointing': [201.59021723, -17.469999313354492, np.float64(1.63115981)]}, {'pointing': [199.8828505, -16.530000686645508, np.float64(1.78716956)]}, {'pointing': [167.4900251, 14.390000343322754, np.float64(1.58082318)]}, {'pointing': [216.68856762, -8.164999961853027, np.float64(3.71145025)]}, {'pointing': [217.24517615, -1.4759999513626099, np.float64(0.15674231)]}, {'pointing': [213.31714573, 0.46939998865127563, np.float64(0.71057843)]}, {'pointing': [214.74986972, -0.11129999905824661, np.float64(0.53099466)]}, {'pointing': [219.08860179, -1.6080000400543213, np.float64(0.50710317)]}, {'pointing': [235.98124333, -8.739999771118164, np.float64(2.94227071)]}, {'pointing': [234.29735131, -4.632999897003174, np.float64(0.44221855)]}, {'pointing': [253.72109195, -0.18780000507831573, np.float64(0.5133336)]}, {'pointing': [286.58773674, -13.970000267028809, np.float64(4.26368021)]}, {'pointing': [276.06605245, -2.6570000648498535, np.float64(0.42800644)]}, {'pointing': [281.70492996, 1.2630000114440918, np.float64(1.83477079)]}, {'pointing': [283.95303862, -0.43779999017715454, np.float64(0.19207717)]}, {'pointing': [285.69880735, -0.4814000129699707, np.float64(0.18820856)]}, {'pointing': [286.5227371, 1.7879999876022339, np.float64(0.2066854)]}, {'pointing': [288.4471836, -0.6414999961853027, np.float64(0.40974585)]}, {'pointing': [289.21446606, -0.7059000134468079, np.float64(0.14652482)]}, {'pointing': [291.15997526, -0.604200005531311, np.float64(0.13881332)]}, {'pointing': [289.263473, 4.822000026702881, np.float64(0.238486)]}, {'pointing': [294.57101719, 0.6747999787330627, np.float64(0.49720768)]}, {'pointing': [299.04262223, -7.326000213623047, np.float64(1.33561559)]}, {'pointing': [299.98870607, -4.826000213623047, np.float64(0.55026432)]}, {'pointing': [303.36979775, 1.815000057220459, np.float64(0.22570083)]}, {'pointing': [301.5468539, -4.376999855041504, np.float64(2.27702188)]}, {'pointing': [309.38873563, -0.28850001096725464, np.float64(0.31591842)]}, {'pointing': [311.99031, -0.8924000263214111, np.float64(0.55761449)]}, {'pointing': [319.67947629, -3.0439999103546143, np.float64(1.11035321)]}, {'pointing': [323.5669228, -5.410999774932861, np.float64(0.35699631)]}, {'pointing': [339.83354568, -0.3075000047683716, np.float64(2.77813434)]}, {'pointing': [355.11587164, 8.041999816894531, np.float64(0.75162882)]}, {'pointing': [349.99941629, 3.0, np.float64(0.44931834)]}, {'pointing': [354.26553406, -1.9129999876022339, np.float64(5.38293647)]}, {'pointing': [8.2454042, -0.946399986743927, np.float64(0.23001168)]}, {'pointing': [15.62646622, 0.9337000250816345, np.float64(0.3189994)]}, {'pointing': [6.06525761, -4.364999771118164, np.float64(0.6457989)]}, {'pointing': [16.16547486, -7.682000160217285, np.float64(2.61957546)]}, {'pointing': [64.40553462, 12.680000305175781, np.float64(2.91523197)]}, {'pointing': [68.00063836, 11.640000343322754, np.float64(3.03645952)]}, {'pointing': [54.82784124, -1.5709999799728394, np.float64(1.45848028)]}, {'pointing': [62.80833477, 2.131999969482422, np.float64(2.69075508)]}, {'pointing': [40.31747184, -10.760000228881836, np.float64(1.09602675)]}, {'pointing': [58.89091481, - ...

# %% [markdown]
# Jaime Villaseñor contributed a catalog of HII regions with massive stars in connection with his Science Pitch.

# %%
catalog_file = path.join(root_dir, 'config', 'villasenor_combined_pointings_table.csv')

pointing_set = []

pixscale = hp.max_pixrad(64,degrees=True)

with open(catalog_file, newline='') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=' ', quotechar='|')
    for i,row in enumerate(csv_reader):
        if i >= 1:
            entries = ''.join(row).split(',')
            radius = np.arctan((float(entries[3])/2.0) / (float(entries[2])*1000.0)) * 180.0/np.pi
            pointing_set.append({"pointing": [float(entries[4]), float(entries[5]), radius],
                                "priority": float(entries[6])})

pointing_set
# Out:
# [{'pointing': [206.5, -16.3, np.float64(0.2604335678133705)], 'priority': 1.0},
#  {'pointing': [209.0, -19.4, np.float64(6.340191745909909)], 'priority': 1.0},
#  {'pointing': [28.8, 3.5, np.float64(0.38586370180906854)], 'priority': 1.0},
#  {'pointing': [265.1, 1.45, np.float64(0.2733355901273604)], 'priority': 1.0},
#  {'pointing': [6.0, -1.2, np.float64(0.21547029179412344)], 'priority': 1.0},
#  {'pointing': [81.22, -0.1, np.float64(4.085616779974877)], 'priority': 1.0},
#  {'pointing': [81.5, 0.6, np.float64(4.085616779974877)], 'priority': 1.0},
#  {'pointing': [78.2, -0.1, np.float64(4.085616779974877)], 'priority': 1.0},
#  {'pointing': [80.6, 0.45, np.float64(4.085616779974877)], 'priority': 1.0},
#  {'pointing': [78.5, 1.25, np.float64(4.085616779974877)], 'priority': 1.0},
#  {'pointing': [7.1, -0.3, np.float64(0.2810025254666298)], 'priority': 1.0},
#  {'pointing': [206.3, -1.7, np.float64(1.7183580016554572)], 'priority': 1.0},
#  {'pointing': [206.3, -2.5, np.float64(1.7183580016554572)], 'priority': 1.0},
#  {'pointing': [207.05, -1.88, np.float64(1.7183580016554572)],
#   'priority': 1.0},
#  {'pointing': [206.3, -2.1, np.float64(1.7183580016554572)], 'priority': 1.0},
#  {'pointing': [268.0, -1.05, np.float64(0.3538811969919822)], 'priority': 1.0},
#  {'pointing': [351.2, 0.7, np.float64(1.667847037994403)], 'priority': 1.0},
#  {'pointing': [353.1, 0.86, np.float64(1.667847037994403)], 'priority': 1.0},
#  {'pointing': [15.1, -0.7, np.float64(2.021364940356016)], 'priority': 1.0},
#  {'pointing': [17.0, 0.8, np.float64(2.021364940356016)], 'priority': 1.0},
#  {'pointing': [75.8, 0.32, np.float64(0.14159273009483087)], 'priority': 1.0},
#  {'pointing': [345.4, 1.4, np.float64(1.6611120451898933)], 'priority': 1.0},
#  {'pointing': [59.7, 0.15, np.float64(2.004534032105904)], 'priority': 1.0},
#  {'pointing': [345.3, 1.0, np.float64(1.6611120451898933)], 'priority': 1.0},
#  {'pointing': [59.4, -0.2, np.float64(2.004534032105904)], 'priority': 1.0},
#  {'pointing': [133.9, 1.15, np.float64(0.22339984306589092)], 'priority': 1.0},
#  {'pointing': [25.4, -0.2, np.float64(0.08594360481195853)], 'priority': 1.0},
#  {'pointing': [134.7, 0.9, np.float64(0.9284173038084015)], 'priority': 1.0},
#  {'pointing': [287.4, -0.5, np.float64(1.3698553966185567)], 'priority': 1.0},
#  {'pointing': [287.5, -0.9, np.float64(1.3698553966185567)], 'priority': 1.0},
#  {'pointing': [287.6, -1.3, np.float64(1.3698553966185567)], 'priority': 1.0},
#  {'pointing': [12.8, -0.2, np.float64(0.20053440944962445)], 'priority': 1.0},
#  {'pointing': [333.5, -0.2, np.float64(0.22036729612316266)], 'priority': 1.0},
#  {'pointing': [333.0, -0.55, np.float64(0.22036729612316266)],
#   'priority': 1.0},
#  {'pointing': [291.3, -0.8, np.float64(0.21511671735162885)], 'priority': 1.0},
#  {'pointing': [111.5, 0.8, np.float64(0.6650104343126745)], 'priority': 1.0},
#  {'pointing': [35.3, -1.8, np.float64(1.6229462240804031)], 'priority': 1.0},
#  {'pointing': [305.3, 0.1, np.float64(0.6798567283434228)], 'priority': 2.0},
#  {'pointing': [284.3, -0.3, np.float64(0.3268428332611555)], 'priority': 2.0},
#  {'pointing': [49.25, -0.35, np.float64(0.5302516832530896)], 'priority': 2.0},
#  {'pointing': [30.8, 0.0, np.float64(0.12500877512230893)], 'priority': 2.0},
#  {'pointing': [30.0, 0.0, np.float64(0.1617215288275695)], 'priority': 2.0},
#  {'pointing': [291.6, -0.5, np.float64(0.2062639151900622)], 'priority': 2.0},
#  {'pointing': [43.2, 0.0, np.float64(0.11157585064257207)], 'priority': 2.0}]
